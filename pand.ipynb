# %%
import pandas as pd
pd.set_option('display.max_rows', None)
parent_folder = "dataset/front/forward/wind_speed_1/head_wind/"

df = pd.read_csv(parent_folder+"drone4test.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_103884/3861178607.py in <module>
#       3 parent_folder = "dataset/front/forward/wind_speed_1/head_wind/"
#       4
# ----> 5 df = pd.read_csv(parent_folder+"drone4test.csv")
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
max(bat["time"])
# Out:
# 640

# %%
bat = pd.read_csv('hovering_battery_consumption.csv')

# %%
bat[["time","bat"]]
# Out:
#       time  bat
# 0        0  100
# 1        0  100
# 2        0  100
# 3        0  100
# 4        0  100
# 5        0  100
# 6        0  100
# 7        0  100
# 8        0  100
# 9        0  100
# 10       0  100
# 11       0  100
# 12       0  100
# 13       1  100
# 14       1  100
# 15       1  100
# 16       1  100
# 17       1  100
# 18       1  100
# 19       1  100
# 20       1  100
# 21       1  100
# 22       1  100
# 23       2  100
# 24       2  100
# 25       2  100
# 26       2  100
# 27       2  100
# 28       2  100
# 29       2  100
# 30       2  100
# 31       2  100
# 32       2  100
# 33       3  100
# 34       3  100
# 35       3  100
# 36       3  100
# 37       3  100
# 38       3  100
# 39       3  100
# 40       3  100
# 41       3  100
# 42       3  100
# 43       4  100
# 44       4  100
# 45       4  100
# 46       4  100
# 47       4  100
# 48       4  100
# 49       4  100
# 50       4  100
# 51       4  100
# 52       4  100
# 53       5  100
# ...

# %%
import matplotlib.pyplot as plt

# plt.plot(bat['bat'],bat['timestamp'])
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_103884/3572694418.py in <module>
#       2
#       3 plt.plot(bat['bat'],bat['timestamp'])
# ----> 4 plt.show()
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     366     """
#     367     _warn_if_gui_out_of_main_thread()
# --> 368     return _backend_mod.show(*args, **kwargs)
#     369
#     370
#
# ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...
